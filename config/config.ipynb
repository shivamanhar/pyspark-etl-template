# %%
CONFIG = {
    'catalog':{
        'name':"workspace",
        'schema':"etl_practice"
    },
    'path':{
        'source':"/Volumes/workspace/etl_practice/my_file",
        'checkpoint':"/Volumes/workspace/etl_practice/my_file/_checkpoints",
        'schema':"/Volumes/workspace/etl_practice/my_file/_schemas"
    },
    'sub_path':
    {
        'customer':'customer',
        'product':'product',
        'sales':'sales'
    }
}

# %%
# table name
TABLES = {
    'bronze':{
        'customer':'bronze_customer',
        'product':'bronze_product',
        'sales':'bronze_fact_sales'
    },
    'silver':
    {
        'customer':'silver_customer',
        'product':'silver_product',
        'sales':'silver_fact_sales'
    },
    'gold':
    {
        'sales_enriched':'gold_sales_enriched',
        'customer':'gold_customer',
        'product':'gold_product'
    }
}

# %%
spark.sql(f"use catalog {CONFIG['catalog']['name']}")
spark.sql(f"use schema {CONFIG['catalog']['schema']}")

# %%
print("The configuration file notebook ran successfully")

# %%
#this is source path
base_path = "/Volumes/workspace/etl_practice/my_file"

# %%
# checkpoint location 
checkpoint_path = f"/Volumes/workspace/etl_practice/my_file/_checkpoints"

# %%
schema_path = f"/Volumes/workspace/etl_practice/my_file/_schemas"

# %%
catalog = "workspace"
schema_name = "etl_practice"

# %%
# bronze layered table name
bronze_customer = 'bronze_customer'
bronze_product_tbl = 'bronze_product'

# silver table name
silver_customer = 'silver_customer'
silver_product = 'silver_product'

# Gold table name
gold_customer = 'gold_customer'
gold_product = 'gold_product'
